# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('Walmart.csv')

# %%
df
# Out:
#             Order ID  Order Date   Ship Date    Customer Name        Country  \
# 0     CA-2013-138688  13-06-2013  17-06-2013  Darrin Van Huff  United States
# 1     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 2     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 3     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 4     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# ...              ...         ...         ...              ...            ...
# 3198  CA-2013-125794  30-09-2013  04-10-2013     Maris LaWare  United States
# 3199  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3200  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3201  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3202  CA-2014-119914  05-05-2014  10-05-2014     Chris Cortes  United States
#
# ...

# %%
df.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Customer Name    0
# Country          0
# City             0
# State            0
# Category         0
# Product Name     0
# Sales            0
# Quantity         0
# Profit           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3203 entries, 0 to 3202
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       3203 non-null   object
#  1   Order Date     3203 non-null   object
#  2   Ship Date      3203 non-null   object
#  3   Customer Name  3203 non-null   object
#  4   Country        3203 non-null   object
#  5   City           3203 non-null   object
#  6   State          3203 non-null   object
#  7   Category       3203 non-null   object
#  8   Product Name   3203 non-null   object
#  9   Sales          3203 non-null   float64
#  10  Quantity       3203 non-null   float64
#  11  Profit         3203 non-null   float64
# dtypes: float64(3), object(9)
# memory usage: 300.4+ KB

# %%
df.describe()
# Out:
#               Sales     Quantity       Profit
# count   3203.000000  3203.000000  3203.000000
# mean     226.493266     3.828910    33.849138
# std      524.876911     2.260947   174.109155
# min        0.990000     1.000000 -3399.980000
# 25%       19.440000     2.000000     3.850000
# 50%       60.840000     3.000000    11.170000
# 75%      215.810000     5.000000    33.000000
# max    13999.960000    14.000000  6719.980000

# %%
plt.figure(figsize=(12,8), dpi = 200)
sns.boxplot(x = 'Sales', data = df)
# Out:
# <AxesSubplot:xlabel='Sales'>

# %%
df[df['Sales']>4000]
# Out:
#             Order ID  Order Date   Ship Date   Customer Name        Country  \
# 799   CA-2011-143917  25-07-2011  27-07-2011    Ken Lonsdale  United States
# 1319  CA-2014-149881  02-04-2014  04-04-2014   Nick Crebassa  United States
# 1913  CA-2013-136301  14-03-2013  16-03-2013    Edward Hooks  United States
# 1973  CA-2013-159016  11-03-2013  12-03-2013  Karen Ferguson  United States
# 2533  CA-2013-138478  22-10-2013  27-10-2013   Dennis Pardue  United States
# 2663  CA-2014-140151  24-03-2014  26-03-2014    Raymond Buch  United States
# 2846  CA-2014-135909  14-10-2014  21-10-2014       Jane Waco  United States
# 2927  CA-2013-100300  25-06-2013  27-06-2013       Max Jones  United States
#
#                  City       State  Category  \
# 799     San Francisco  California  Supplies
# 1319    San Francisco  California  Machines
# 1913    San Francisco  California  Supplies
# 1973      Los Angeles  California    Phones
# 2533  North Las Vegas      Nevada   Binders
# ...

# %%
#df[["Order Date","Ship Date"]]=df[["Order Date","Ship Date"]].apply(pd.to_datetime())

# %%
df = df[df['Sales']<8000]

# %%
df
# Out:
#             Order ID  Order Date   Ship Date    Customer Name        Country  \
# 0     CA-2013-138688  13-06-2013  17-06-2013  Darrin Van Huff  United States
# 1     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 2     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 3     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 4     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# ...              ...         ...         ...              ...            ...
# 3198  CA-2013-125794  30-09-2013  04-10-2013     Maris LaWare  United States
# 3199  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3200  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3201  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3202  CA-2014-119914  05-05-2014  10-05-2014     Chris Cortes  United States
#
# ...

# %%
df = df[df['Profit']<6000]

# %%
df
# Out:
#             Order ID  Order Date   Ship Date    Customer Name        Country  \
# 0     CA-2013-138688  13-06-2013  17-06-2013  Darrin Van Huff  United States
# 1     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 2     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 3     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 4     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# ...              ...         ...         ...              ...            ...
# 3198  CA-2013-125794  30-09-2013  04-10-2013     Maris LaWare  United States
# 3199  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3200  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3201  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3202  CA-2014-119914  05-05-2014  10-05-2014     Chris Cortes  United States
#
# ...

# %%
plt.figure(figsize=(12,8), dpi = 200)
sns.boxplot(x = 'Sales', data = df)
# Out:
# <AxesSubplot:xlabel='Sales'>

# %%
df.describe()
# Out:
#              Sales     Quantity       Profit
# count  3201.000000  3201.000000  3201.000000
# mean    219.703318     3.828491    31.668635
# std     443.318974     2.261557   127.793313
# min       0.990000     1.000000 -3399.980000
# 25%      19.440000     2.000000     3.850000
# 50%      60.810000     3.000000    11.170000
# 75%     215.590000     5.000000    32.930000
# max    5083.960000    14.000000  1906.490000

# %%
Categories_sales = df.groupby('Category')['Sales'].sum()

# %%
Categories_sales
# Out:
# Category
# Accessories     61114.10
# Appliances      30236.32
# Art              9212.06
# Binders         55961.11
# Bookcases       36004.18
# Chairs         101781.36
# Copiers         35749.27
# Envelopes        4118.10
# Fasteners         923.20
# Furnishings     30072.73
# Labels           5078.72
# Machines        42444.14
# Paper           26663.73
# Phones          98684.39
# Storage         70532.84
# Supplies         9939.47
# Tables          84754.60
# Name: Sales, dtype: float64

# %%
Categories_quantities = df.groupby('Category')['Quantity'].sum().sort_values(ascending=True)

# %%
Categories_quantities
# Out:
# Category
# Copiers          84.0
# Machines        147.0
# Envelopes       227.0
# Supplies        233.0
# Fasteners       263.0
# Bookcases       306.0
# Labels          480.0
# Tables          481.0
# Appliances      492.0
# Chairs          734.0
# Art             926.0
# Accessories    1032.0
# Storage        1039.0
# Phones         1066.0
# Furnishings    1175.0
# Paper          1702.0
# Binders        1868.0
# Name: Quantity, dtype: float64

# %%
plt.figure(figsize=(12,6), dpi = 100)
Categories_quantities.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
df['Quantity'] = df['Quantity'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3201 entries, 0 to 3202
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       3201 non-null   object
#  1   Order Date     3201 non-null   object
#  2   Ship Date      3201 non-null   object
#  3   Customer Name  3201 non-null   object
#  4   Country        3201 non-null   object
#  5   City           3201 non-null   object
#  6   State          3201 non-null   object
#  7   Category       3201 non-null   object
#  8   Product Name   3201 non-null   object
#  9   Sales          3201 non-null   float64
#  10  Quantity       3201 non-null   int32
#  11  Profit         3201 non-null   float64
# dtypes: float64(2), int32(1), object(9)
# memory usage: 312.6+ KB

# %%
plt.figure(figsize=(12,6), dpi  = 100)
sns.histplot(data = df, x='Category', y = 'Profit')
plt.xticks(rotation = 90);
plt.ylim(-1000,2000)
# Out:
# (-1000.0, 2000.0)

# %%
df[['Category','Profit']]
# Out:
#          Category  Profit
# 0          Labels    6.87
# 1     Furnishings   14.17
# 2             Art    1.97
# 3          Phones   90.72
# 4         Binders    5.78
# ...           ...     ...
# 3198  Accessories   15.22
# 3199  Furnishings   15.63
# 3200       Phones   19.39
# 3201        Paper   13.32
# 3202   Appliances   72.95
#
# [3201 rows x 2 columns]

# %%
df.groupby('Category')['Profit'].sum().sort_values(ascending = True)
# Out:
# Category
# Bookcases      -1646.50
# Machines        -618.95
# Fasteners        275.19
# Supplies         298.60
# Tables          1482.54
# Envelopes       1908.71
# Labels          2303.07
# Art             2374.15
# Chairs          4027.62
# Furnishings     7641.26
# Appliances      8261.29
# Storage         8645.49
# Phones          9111.06
# Paper          12119.10
# Copiers        12607.27
# Binders        16096.78
# Accessories    16484.62
# Name: Profit, dtype: float64

# %%
df
# Out:
#             Order ID  Order Date   Ship Date    Customer Name        Country  \
# 0     CA-2013-138688  13-06-2013  17-06-2013  Darrin Van Huff  United States
# 1     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 2     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 3     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 4     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# ...              ...         ...         ...              ...            ...
# 3198  CA-2013-125794  30-09-2013  04-10-2013     Maris LaWare  United States
# 3199  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3200  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3201  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3202  CA-2014-119914  05-05-2014  10-05-2014     Chris Cortes  United States
#
# ...

# %%
df.Sales.sort_values(ascending=True)
# Out:
# 879        0.99
# 295        1.08
# 1576       1.08
# 1995       1.19
# 2309       1.34
#          ...
# 2927    4476.80
# 2533    4535.98
# 1319    4799.98
# 1913    4912.59
# 2846    5083.96
# Name: Sales, Length: 3201, dtype: float64

# %%
df[['State', 'Sales']]
# Out:
#            State   Sales
# 0     California   14.62
# 1     California   48.86
# 2     California    7.28
# 3     California  907.15
# 4     California   18.50
# ...          ...     ...
# 3198  California   36.24
# 3199  California   91.96
# 3200  California  258.58
# 3201  California   29.60
# 3202  California  243.16
#
# [3201 rows x 2 columns]

# %%
state_sales = df.groupby('State')['Sales'].sum().sort_values(ascending = True)

# %%
state_sales_tab = pd.DataFrame(state_sales)

# %%
state_sales_tab.plot(kind = 'bar')
plt.grid()

# %%
df[['Order Date', 'Sales']]
# Out:
#       Order Date   Sales
# 0     13-06-2013   14.62
# 1     09-06-2011   48.86
# 2     09-06-2011    7.28
# 3     09-06-2011  907.15
# 4     09-06-2011   18.50
# ...          ...     ...
# 3198  30-09-2013   36.24
# 3199  27-02-2014   91.96
# 3200  27-02-2014  258.58
# 3201  27-02-2014   29.60
# 3202  05-05-2014  243.16
#
# [3201 rows x 2 columns]

# %%
order_sales = df.groupby('Order Date')['Sales'].sum().sort_values(ascending = True)

# %%
order_sales
# Out:
# Order Date
# 10-07-2014       1.08
# 19-07-2012       2.03
# 09-11-2012       2.48
# 06-09-2014       2.78
# 08-03-2012       3.41
#                ...
# 22-10-2013    5477.85
# 26-12-2013    5820.45
# 19-08-2014    6522.65
# 01-12-2012    6956.64
# 11-03-2013    7662.96
# Name: Sales, Length: 845, dtype: float64

# %%
plt.figure(figsize=(12,6))
order_sales.plot()
plt.xticks(rotation = 90);

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x="Sales", y="Profit", data=df)
plt.title('Sales vs. Profit')
plt.ylabel('Profit')
plt.xlabel('Sales')
plt.show()

# %% [markdown]
# # ML MODELS

# %%
backup_df = df.copy()

# %%
backup_df
# Out:
#             Order ID  Order Date   Ship Date    Customer Name        Country  \
# 0     CA-2013-138688  13-06-2013  17-06-2013  Darrin Van Huff  United States
# 1     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 2     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 3     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 4     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# ...              ...         ...         ...              ...            ...
# 3198  CA-2013-125794  30-09-2013  04-10-2013     Maris LaWare  United States
# 3199  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3200  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3201  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3202  CA-2014-119914  05-05-2014  10-05-2014     Chris Cortes  United States
#
# ...

# %% [markdown]
# # Importing Necessary libaries for K-Means Clustering

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.cluster import KMeans

# %% [markdown]
# Turning Catogorial values into numbers by assigning each category to a specific number. This is done by LabelEncoder

# %%
# label = LabelEncoder()

# %%
# backup_df['Country'] = label.fit_transform(backup_df['Country'])
# backup_df['Customer Name'] = label.fit_transform(backup_df['Customer Name'])
# backup_df['City'] = label.fit_transform(backup_df['City'])
# backup_df['State'] = label.fit_transform(backup_df['State'])
# backup_df['Category'] = label.fit_transform(backup_df['Category'])
# backup_df['Product Name'] = label.fit_transform(backup_df['Product Name'])

# %%
backup_df['Customer Name']
# Out:
# 0       Darrin Van Huff
# 1       Brosina Hoffman
# 2       Brosina Hoffman
# 3       Brosina Hoffman
# 4       Brosina Hoffman
#              ...
# 3198       Maris LaWare
# 3199        Dave Brooks
# 3200        Dave Brooks
# 3201        Dave Brooks
# 3202       Chris Cortes
# Name: Customer Name, Length: 3201, dtype: object

# %%
df['Customer Name']
# Out:
# 0       Darrin Van Huff
# 1       Brosina Hoffman
# 2       Brosina Hoffman
# 3       Brosina Hoffman
# 4       Brosina Hoffman
#              ...
# 3198       Maris LaWare
# 3199        Dave Brooks
# 3200        Dave Brooks
# 3201        Dave Brooks
# 3202       Chris Cortes
# Name: Customer Name, Length: 3201, dtype: object

# %% [markdown]
# StandardScaler performs the task of Standardization. Usually a dataset contains variables that are different in scale. For e.g. an Employee dataset will contain AGE column with values on scale 20-70 and SALARY column with values on scale 10000-80000. As these two columns are different in scale, they are Standardized to have common scale while building machine learning model.

# %%
backup_df
# Out:
#             Order ID  Order Date   Ship Date    Customer Name        Country  \
# 0     CA-2013-138688  13-06-2013  17-06-2013  Darrin Van Huff  United States
# 1     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 2     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 3     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 4     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# ...              ...         ...         ...              ...            ...
# 3198  CA-2013-125794  30-09-2013  04-10-2013     Maris LaWare  United States
# 3199  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3200  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3201  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3202  CA-2014-119914  05-05-2014  10-05-2014     Chris Cortes  United States
#
# ...

# %%
scaler = StandardScaler()
backup_df[["Sales", "Quantity", "Profit"]] = scaler.fit_transform(backup_df[["Sales", "Quantity", "Profit"]])

# %%
backup_df
# Out:
#             Order ID  Order Date   Ship Date    Customer Name        Country  \
# 0     CA-2013-138688  13-06-2013  17-06-2013  Darrin Van Huff  United States
# 1     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 2     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 3     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 4     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# ...              ...         ...         ...              ...            ...
# 3198  CA-2013-125794  30-09-2013  04-10-2013     Maris LaWare  United States
# 3199  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3200  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3201  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3202  CA-2014-119914  05-05-2014  10-05-2014     Chris Cortes  United States
#
# ...

# %% [markdown]
# Running actual K-Means model based on those 3 Columns

# %%
kmeans = KMeans(n_clusters=4, random_state=42)

# %%
backup_df['Clusters'] = kmeans.fit_predict(backup_df[['Sales', 'Quantity', 'Profit']])

# %%
backup_df
# Out:
#             Order ID  Order Date   Ship Date    Customer Name        Country  \
# 0     CA-2013-138688  13-06-2013  17-06-2013  Darrin Van Huff  United States
# 1     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 2     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 3     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 4     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# ...              ...         ...         ...              ...            ...
# 3198  CA-2013-125794  30-09-2013  04-10-2013     Maris LaWare  United States
# 3199  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3200  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3201  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3202  CA-2014-119914  05-05-2014  10-05-2014     Chris Cortes  United States
#
# ...

# %%
backup_df['Clusters'].unique()
# Out:
# array([0, 1, 3, 2])

# %% [markdown]
# # Plotting the findings

# %%
# visualize the clusters
plt.figure(figsize=(12,6), dpi = 100)
sns.scatterplot(data=backup_df, x="Sales", y="Profit", hue="Clusters")
plt.title("Customer Segmentation using K-Means Clustering")
plt.show()

# %% [markdown]
# # Choosing K Value Using ELBOW Method

# %%
ssd = []

for k in range(2,10):
    
    model = KMeans(n_clusters=k)
    
    
    model.fit(backup_df[['Sales', 'Quantity', 'Profit']])
    
    #Sum of squared distances of samples to their closest cluster center.
    ssd.append(model.inertia_)

# %%
plt.plot(range(2,10),ssd,'o--')
plt.xlabel("K Value")
plt.ylabel(" Sum of Squared Distances")
# Out:
# Text(0, 0.5, ' Sum of Squared Distances')

# %%
ssd
# Out:
# [6532.710467631424,
#  4559.398282771125,
#  3814.921676673568,
#  3071.297412463307,
#  2601.239953622915,
#  2281.3343087429944,
#  1999.9196055875445,
#  1751.7570534735726]

# %%
pd.Series(ssd).diff()
# Out:
# 0            NaN
# 1   -1973.312185
# 2    -744.476606
# 3    -743.624264
# 4    -470.057459
# 5    -319.905645
# 6    -281.414703
# 7    -248.162552
# dtype: float64

# %%
pd.Series(ssd).diff().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Lets Consider K-value = 3

# %%
kmeans = KMeans(n_clusters=3, random_state=42)

# %%
backup_df['Cluster1'] = kmeans.fit_predict(backup_df[['Sales','Quantity', 'Profit']])

# %%
backup_df['Cluster1']
# Out:
# 0       1
# 1       2
# 2       1
# 3       1
# 4       1
#        ..
# 3198    1
# 3199    1
# 3200    1
# 3201    1
# 3202    1
# Name: Cluster1, Length: 3201, dtype: int32

# %%
#backup_df[backup_df['Cluster1']]

# %%
backup_df
# Out:
#             Order ID  Order Date   Ship Date    Customer Name        Country  \
# 0     CA-2013-138688  13-06-2013  17-06-2013  Darrin Van Huff  United States
# 1     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 2     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 3     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 4     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# ...              ...         ...         ...              ...            ...
# 3198  CA-2013-125794  30-09-2013  04-10-2013     Maris LaWare  United States
# 3199  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3200  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3201  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3202  CA-2014-119914  05-05-2014  10-05-2014     Chris Cortes  United States
#
# ...

# %%
backup_df = backup_df.drop('Clusters', axis = 1)

# %%
backup_df[['Cluster1']]
# Out:
#       Cluster1
# 0            1
# 1            2
# 2            1
# 3            1
# 4            1
# ...        ...
# 3198         1
# 3199         1
# 3200         1
# 3201         1
# 3202         1
#
# [3201 rows x 1 columns]

# %%
# visualize the clusters
plt.figure(figsize=(12,6), dpi = 100)
sns.scatterplot(data=backup_df, x="Sales", y="Profit", hue="Cluster1")
plt.title("Customer Segmentation using K-Means Clustering")
plt.ylim(-10,20)
plt.show()

# %%
Cluster_0 = backup_df[backup_df['Cluster1'] == 0]

# %%
Cluster_1 = backup_df[backup_df['Cluster1'] == 1]

# %%
Cluster_2 = backup_df[backup_df['Cluster1'] == 2]

# %%
Cluster_0
# Out:
#             Order ID  Order Date   Ship Date        Customer Name  \
# 6     CA-2011-115812  09-06-2011  14-06-2011      Brosina Hoffman
# 13    CA-2012-106320  25-09-2012  30-09-2012          Emily Burns
# 72    CA-2013-145625  12-09-2013  18-09-2013      Kelly Collister
# 97    CA-2012-137946  01-09-2012  04-09-2012        Doug Bickford
# 111   US-2011-135972  21-09-2011  23-09-2011           Jack Garza
# ...              ...         ...         ...                  ...
# 3084  CA-2013-107104  27-11-2013  01-12-2013  Maribeth Schnelling
# 3091  CA-2013-160717  07-06-2013  12-06-2013        Maria Etezadi
# 3134  CA-2013-146913  01-11-2013  06-11-2013      Sylvia Foulston
# 3161  CA-2012-164301  26-03-2012  30-03-2012        Ellis Ballard
# 3177  CA-2013-129630  05-09-2013  05-09-2013        Ionia McGrath
#
#             Country           City       State     Category  \
# 6     United States    Los Angeles  California       Tables
# ...

# %%
Cluster_0['Category'].unique()
# Out:
# array(['Tables', 'Accessories', 'Copiers', 'Storage', 'Furnishings',
#        'Phones', 'Appliances', 'Labels', 'Binders', 'Bookcases',
#        'Machines', 'Chairs', 'Paper', 'Supplies'], dtype=object)

# %%
Cluster_1
# Out:
#             Order ID  Order Date   Ship Date    Customer Name        Country  \
# 0     CA-2013-138688  13-06-2013  17-06-2013  Darrin Van Huff  United States
# 2     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 3     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 4     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 7     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# ...              ...         ...         ...              ...            ...
# 3198  CA-2013-125794  30-09-2013  04-10-2013     Maris LaWare  United States
# 3199  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3200  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3201  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3202  CA-2014-119914  05-05-2014  10-05-2014     Chris Cortes  United States
#
# ...

# %%
Cluster_1['Category'].unique()
# Out:
# array(['Labels', 'Art', 'Phones', 'Binders', 'Storage', 'Accessories',
#        'Paper', 'Furnishings', 'Tables', 'Chairs', 'Fasteners',
#        'Envelopes', 'Appliances', 'Supplies', 'Bookcases', 'Machines',
#        'Copiers'], dtype=object)

# %%
Cluster_2
# Out:
#             Order ID  Order Date   Ship Date    Customer Name        Country  \
# 1     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 5     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 18    CA-2012-135545  24-11-2012  30-11-2012     Kunst Miller  United States
# 21    CA-2011-106376  05-12-2011  10-12-2011    Brendan Sweed  United States
# 23    CA-2011-139451  12-10-2011  16-10-2011     Duane Noonan  United States
# ...              ...         ...         ...              ...            ...
# 3184  CA-2011-143371  28-12-2011  03-01-2012    Maribeth Dona  United States
# 3191  US-2013-103674  07-12-2013  11-12-2013       Anne Pryor  United States
# 3192  US-2013-103674  07-12-2013  11-12-2013       Anne Pryor  United States
# 3195  US-2013-103674  07-12-2013  11-12-2013       Anne Pryor  United States
# 3197  US-2013-103674  07-12-2013  11-12-2013       Anne Pryor  United States
#
# ...
